# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('A.csv')
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Wheezing'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Fatigue'],color='blue')
# Out:
# (array([110., 211., 212., 180.,   0.,  89.,  50.,   0., 109.,  39.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
df['OccuPational Hazards'].hist(figsize=(10,5),color='red')
# Out:
# <Axes: >

# %%
plt.bar(df['Genetic Risk'],df['Passive Smoker'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.boxplot(df['Swallowing Difficulty'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x223ad81d3f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x223ad81d810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x223ad81d150>],
#  'medians': [<matplotlib.lines.Line2D at 0x223ad81dd50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x223ad81dff0>],
#  'means': []}

# %%
df['Clubbing of Finger Nails'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['Level'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(df['Passive Smoker'],df['Chest Pain'], color='red') # residplot, scatterplot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.residplot(df['Passive Smoker'],df['Chest Pain'], color='red')
#
# TypeError: residplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(30,25))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)

# %%
def plot(d, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Level')
